# %% [markdown]
# ## Plot 8: Fairness-Efficiency Frontier Across Scales
#
# How does the fundamental fairness-efficiency trade-off evolve with worker count?

# %% [markdown]
# ## Plot 12: Worker Idle Time Distribution (NEW v2.0!)
#
# Examining how idle time distribution changes with worker density - **showcasing newly implemented metrics**.

# %% [markdown]
# ## Plot 13: Travel Efficiency at Scale
#
# How do travel-related metrics (distance, empty-km ratio) change with worker density?
